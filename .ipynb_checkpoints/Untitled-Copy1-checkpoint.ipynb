# %%
import mols2grid
mols2grid.display(r"C:\Users\navee\JUPYTER NOTEBOOKS\Graph-ML POCs\sdf_material_files/all_GRPF_chemicals.sdf")
# Out:
# [16:40:48] Warning: molecule is tagged as 3D, but all Z coords are zero
# <script>
#     function fit_height(obj) {
#         obj.style.height = 0;
#         var height = obj.contentDocument.body.scrollHeight + 18 + 'px';
#         obj.style.height = height;
#     }
# </script>
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
# height="200"
#
#
# allow="clipboard-write"
#
# srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#     #mols2grid.gridcontainer {
#     display: block;
#     padding-left: 1em;
#     max-width: 820px;
#     width: 820px;
# }
# #mols2grid .cell {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 160px;
#     width: 160px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12pt;
#     padding: 0;
#     margin: 0px;
#     float: left;
# }
# #mols2grid .cell:hover {
#     background-color: #e7e7e7 !important;
# }
# ...
